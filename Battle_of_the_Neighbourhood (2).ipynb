# %% [markdown]
# # Battle of the Neighbourhoods

# %% [markdown]
# This Note book holds the cleaning of the data from the data sets that were found, the visualisation and the Foursquare part of this task. The report that analyses the information and data in this NoteBook can be found on GitHub.

# %% [markdown]
# The data has been found on the loacal authorities online databases. The problem that will be resolved using these data frames is to find the best place to live or open up a business comparing two big cities in two different countries, New York City and London.

# %% [markdown]
# ### Arrest rate data frame in NYC

# %% [markdown]
# The next few lines of code are to clean the arrest rate for NYC.

# %%
import pandas as pd

data_arrest_NYC = pd.read_csv("https://raw.githubusercontent.com/Heather-Tymms/Coursera_Capstone/master/NYPD_Arrest_Data__Year_to_Date_.csv")

# %%
data_arrest_NYC.shape
# Out:
# (113651, 18)

# %%
columns_to_drop = data_arrest_NYC[["ARREST_KEY", "ARREST_DATE", "PD_CD", "PD_DESC", "KY_CD", "LAW_CODE", "LAW_CAT_CD", "X_COORD_CD", "Y_COORD_CD"]]
arrest_NYC = data_arrest_NYC.drop(columns = columns_to_drop, axis = 1, inplace = False)
arrest_NYC.head()
# Out:
#                   OFNS_DESC ARREST_BORO  ARREST_PRECINCT  JURISDICTION_CODE  \
# 0            FELONY ASSAULT           K               78                  0
# 1                  BURGLARY           Q              104                  0
# 2         DANGEROUS WEAPONS           K               73                  0
# 3  VEHICLE AND TRAFFIC LAWS           Q              104                  0
# 4             PETIT LARCENY           K               90                  0
#
#   AGE_GROUP PERP_SEX       PERP_RACE   Latitude  Longitude
# 0       <18        M           BLACK  40.680570 -73.983925
# 1     25-44        M           BLACK  40.693587 -73.902781
# 2     18-24        M           BLACK  40.675770 -73.915162
# 3     25-44        M  WHITE HISPANIC  40.712596 -73.880699
# 4     45-64        M  WHITE HISPANIC  40.703249 -73.944275

# %%
arrest_NYC["ARREST_BORO"].unique()
# Out:
# array(['K', 'Q', 'M', 'B', 'S'], dtype=object)

# %%
arrest_NYC["ARREST_BORO"].replace(to_replace = "B", value = "Bronx", inplace = True, regex=True)

# %%
arrest_NYC["ARREST_BORO"].replace(to_replace = "S", value = "Staton Island", inplace = True, regex=True)

# %%
arrest_NYC["ARREST_BORO"].replace(to_replace = "K", value = "Brooklyn", inplace = True, regex=True)

# %%
arrest_NYC["ARREST_BORO"].replace(to_replace = "M", value = "Manhatton", inplace = True, regex=True)

# %%
arrest_NYC["ARREST_BORO"].replace(to_replace = "Q", value = "Queens", inplace = True, regex=True)

# %%
URL_pop = "https://raw.githubusercontent.com/Heather-Tymms/Coursera_Capstone/master/NYC_Population_by_Borough.csv"
data_pop_NYC= pd.read_csv(URL_pop, sep=',')
data_pop_NYC
# Out:
#          Borough  Population
# 0       Brooklyn     4970026
# 1      Manhattan     3123068
# 2          Bronx     2717758
# 3         Queens     4460101
# 4  Staten Island      912458

# %%
arrestsNYC = arrest_NYC["ARREST_BORO"].value_counts().to_frame(name = "Arrest_Numbers")
arrestsNYC.reset_index(inplace=True)
arrestsNYC=arrestsNYC.rename(columns={"index": "BOROUGH"})
arrestsNYC
# Out:
#          BOROUGH  Arrest_Numbers
# 0       Brooklyn           31127
# 1      Manhatton           28206
# 2          Bronx           25866
# 3         Queens           23575
# 4  Staton Island            4877

# %%
arr = pd.concat([arrestsNYC, data_pop_NYC], axis=1)
arr
# Out:
#          BOROUGH  Arrest_Numbers        Borough  Population
# 0       Brooklyn           31127       Brooklyn     4970026
# 1      Manhatton           28206      Manhattan     3123068
# 2          Bronx           25866          Bronx     2717758
# 3         Queens           23575         Queens     4460101
# 4  Staton Island            4877  Staten Island      912458

# %%
arr= arr.drop("Borough", axis=1, inplace=False)
arr= arr.set_index("BOROUGH")
arr
# Out:
#                Arrest_Numbers  Population
# BOROUGH
# Brooklyn                31127     4970026
# Manhatton               28206     3123068
# Bronx                   25866     2717758
# Queens                  23575     4460101
# Staton Island            4877      912458

# %%
arr["arrest_per_thousand"]= (arr["Arrest_Numbers"]/arr["Population"])*1000

# %%
arrest= arr.drop(columns=["Arrest_Numbers","Population"], axis =1, inplace=False)

# %%
arrest = arrest.sort_index()

# %% [markdown]
# This shows the number of arrests in a 4 year period in each borough of NYC.

# %%
arrest= arrest.reset_index()
arrest
# Out:
#          BOROUGH  arrest_per_thousand
# 0          Bronx             9.517404
# 1       Brooklyn             6.262945
# 2      Manhatton             9.031504
# 3         Queens             5.285755
# 4  Staton Island             5.344904

# %% [markdown]
# ### Housing prices in NYC

# %% [markdown]
# This part is tp clean the housig price data  from NYC.

# %%
import numpy as np
data_house_NYC = pd.read_csv("https://raw.githubusercontent.com/Heather-Tymms/Coursera_Capstone/master/2018_citywide_sale_open.csv")
data_house_NYC.head()
# Out:
#       BOROUGH   BUILDING CLASS CATEGORY  NUMBER OF SALES  MINIMUM SALE PRICE  \
# 0   Manhattan  01 ONE FAMILY HOMES                    89            200000.0
# 1   Manhattan  02 TWO FAMILY HOMES                    74            424797.0
# 2   Manhattan  03 THREE FAMILY HOMES                  40            816425.0
# 3       Bronx  01 ONE FAMILY HOMES                   970            200000.0
# 4       Bronx  02 TWO FAMILY HOMES                  1409            200000.0
#
#    AVERAGE SALE PRICE  MEDIAN SALE PRICE  MAXIMUM SALE PRICE
# 0           8235346.0          6350000.0          41000000.0
# 1           5620562.0          3725000.0          43500000.0
# 2           5684533.0          2965000.0          27400000.0
# 3            499060.0           425000.0          12303058.0
# 4            523501.0           512000.0           5400000.0

# %%
columns = data_house_NYC[["BUILDING CLASS CATEGORY", "NUMBER OF SALES", "MINIMUM SALE PRICE", "MAXIMUM SALE PRICE"]]
data_house_NYC = data_house_NYC.drop(labels=columns, axis =1)

# %%
housing_NYC  = data_house_NYC.groupby(by= "BOROUGH", axis=0, as_index=True).mean()

# %%
housing_NYC
# Out:
#                 AVERAGE SALE PRICE  MEDIAN SALE PRICE
# BOROUGH
#  Bronx                5.359810e+05       5.123333e+05
#  Brooklyn             1.087048e+06       8.871667e+05
#  Citywide             8.781680e+05       6.916667e+05
#  Manhattan            6.513480e+06       4.346667e+06
#  Queens               7.993533e+05       7.546667e+05
#  Staten Island        5.594600e+05       5.422230e+05

# %%
housing_NYC = housing_NYC.reset_index(inplace=False)

# %%
housing_NYC = housing_NYC.drop([2])
housing_NYC = housing_NYC.reset_index()

# %%
housing_NYC = housing_NYC.drop("BOROUGH", axis=1, inplace=False)

# %%
NYC = pd.concat([arrest,housing_NYC],axis=1)

# %%
NYC
# Out:
#          BOROUGH  arrest_per_thousand  index  AVERAGE SALE PRICE  \
# 0          Bronx             9.517404      0        5.359810e+05
# 1       Brooklyn             6.262945      1        1.087048e+06
# 2      Manhatton             9.031504      3        6.513480e+06
# 3         Queens             5.285755      4        7.993533e+05
# 4  Staton Island             5.344904      5        5.594600e+05
#
#    MEDIAN SALE PRICE
# 0       5.123333e+05
# 1       8.871667e+05
# 2       4.346667e+06
# 3       7.546667e+05
# 4       5.422230e+05

# %%
NYC= NYC.set_index('BOROUGH')
NYC
# Out:
#                arrest_per_thousand  index  AVERAGE SALE PRICE  \
# BOROUGH
# Bronx                     9.517404      0        5.359810e+05
# Brooklyn                  6.262945      1        1.087048e+06
# Manhatton                 9.031504      3        6.513480e+06
# Queens                    5.285755      4        7.993533e+05
# Staton Island             5.344904      5        5.594600e+05
#
#                MEDIAN SALE PRICE
# BOROUGH
# Bronx               5.123333e+05
# Brooklyn            8.871667e+05
# Manhatton           4.346667e+06
# Queens              7.546667e+05
# Staton Island       5.422230e+05

# %%
NYC = NYC.drop("index",axis=1)
NYC
# Out:
#                arrest_per_thousand  AVERAGE SALE PRICE  MEDIAN SALE PRICE
# BOROUGH
# Bronx                     9.517404        5.359810e+05       5.123333e+05
# Brooklyn                  6.262945        1.087048e+06       8.871667e+05
# Manhatton                 9.031504        6.513480e+06       4.346667e+06
# Queens                    5.285755        7.993533e+05       7.546667e+05
# Staton Island             5.344904        5.594600e+05       5.422230e+05

# %%
NYC = NYC.drop("AVERAGE SALE PRICE", axis=1)

# %% [markdown]
# ### Crime rates and house prices in LONDON, UK

# %% [markdown]
# These few lines of code are to clean the data for London.

# %%
URL_UK = "https://raw.githubusercontent.com/Heather-Tymms/Coursera_Capstone/master/london-borough-profiles.csv"
crime_UK = pd.read_csv(URL_UK, sep= ",", na_values = ".", keep_default_na=False, encoding= "ISO-8859-1")
crime_UK.head()
# Out:
#         Code             Area_name Inner/_Outer_London  \
# 0  E09000001        City of London        Inner London
# 1  E09000002  Barking and Dagenham        Outer London
# 2  E09000003                Barnet        Outer London
# 3  E09000004                Bexley        Outer London
# 4  E09000005                 Brent        Outer London
#
#    GLA_Population_Estimate_2017  GLA_Household_Estimate_2017  \
# 0                          8800                       5326.0
# 1                        209000                      78188.0
# 2                        389600                     151423.0
# 3                        244300                      97736.0
# 4                        332100                     121048.0
#
#   Inland_Area_(Hectares)  Population_density_(per_hectare)_2017  \
# 0                    290                                   30.3
# 1                  3,611                                   57.9
# 2                  8,675                                   44.9
# 3                  6,058                                   40.3
# 4                  4,323                                   76.8
#
#    Average_Age,_2017  Proportion_of_population_aged_0-15,_2015  \
# 0               43.2                                      11.4
# 1               32.9                                      27.2
# 2               37.3                                      21.1
# 3               39.0                                      20.6
# 4               35.6                                      20.9
#
#    Proportion_of_population_of_working-age,_2015  ...  \
# 0                                           73.1  ...
# 1                                           63.1  ...
# 2                                           64.9  ...
# 3                                           62.9  ...
# 4                                           67.8  ...
#
#    Happiness_score_2011-14_(out_of_10) Anxiety_score_2011-14_(out_of_10)  \
# 0                                  6.0                               5.6
# 1                                  7.1                               3.1
# 2                                  7.4                               2.8
# 3                                  7.2                               3.3
# 4                                  7.2                               2.9
#
#   Childhood_Obesity_Prevalance_(%)_2015/16 People_aged_17+_with_diabetes_(%)  \
# 0                                      n/a                               2.6
# 1                                     28.5                               7.3
# 2                                     20.7                                 6
# 3                                     22.7                               6.9
# 4                                     24.3                               7.9
#
#    Mortality_rate_from_causes_considered_preventable_2012/14  \
# 0                                              129.0
# 1                                              228.0
# 2                                              134.0
# 3                                              164.0
# 4                                              169.0
#
#   Political_control_in_council  \
# 0                          NaN
# 1                          Lab
# 2                         Cons
# 3                         Cons
# 4                          Lab
#
#    Proportion_of_seats_won_by_Conservatives_in_2014_election  \
# 0                                                NaN
# 1                                                0.0
# 2                                               50.8
# 3                                               71.4
# 4                                                9.5
#
#   Proportion_of_seats_won_by_Labour_in_2014_election  \
# 0                                                NaN
# 1                                              100.0
# 2                                                NaN
# 3                                               23.8
# 4                                               88.9
#
#    Proportion_of_seats_won_by_Lib_Dems_in_2014_election  \
# 0                                                NaN
# 1                                                0.0
# 2                                                1.6
# 3                                                0.0
# 4                                                1.6
#
#   Turnout_at_2014_local_elections
# 0                             NaN
# 1                            36.5
# 2                            40.5
# 3                            39.6
# 4                            36.3
#
# [5 rows x 84 columns]

# %%
crime_lon = crime_UK[["Area_name", 'Crime_rates_per_thousand_population_2014/15', 'Median_House_Price,_2015']]

# %%
crime_UK.columns
# Out:
# Index(['Code', 'Area_name', 'Inner/_Outer_London',
#        'GLA_Population_Estimate_2017', 'GLA_Household_Estimate_2017',
#        'Inland_Area_(Hectares)', 'Population_density_(per_hectare)_2017',
#        'Average_Age,_2017', 'Proportion_of_population_aged_0-15,_2015',
#        'Proportion_of_population_of_working-age,_2015',
#        'Proportion_of_population_aged_65_and_over,_2015',
#        'Net_internal_migration_(2015)', 'Net_international_migration_(2015)',
#        'Net_natural_change_(2015)',
#        '%_of_resident_population_born_abroad_(2015)',
#        'Largest_migrant_population_by_country_of_birth_(2011)',
#        '%_of_largest_migrant_population_(2011)',
#        'Second_largest_migrant_population_by_country_of_birth_(2011)',
#        '%_of_second_largest_migrant_population_(2011)',
#        'Third_largest_migrant_population_by_country_of_birth_(2011)',
#        '%_of_third_largest_migrant_population_(2011)',
#        '%_of_population_from_BAME_groups_(2016)',
#        '%_people_aged_3+_whose_main_language_is_not_English_(2011_Census)',
#        'Overseas_nationals_entering_the_UK_(NINo),_(2015/16)',
#        'New_migrant_(NINo)_rates,_(2015/16)',
#        'Largest_migrant_population_arrived_during_2015/16',
#        'Second_largest_migrant_population_arrived_during_2015/16',
#        'Third_largest_migrant_population_arrived_during_2015/16',
#        'Employment_rate_(%)_(2015)', 'Male_employment_rate_(2015)',
#        'Female_employment_rate_(2015)', 'Unemployment_rate_(2015)',
#        'Youth_Unemployment_(claimant)_rate_18-24_(Dec-15)',
#        'Proportion_of_16-18_year_olds_who_are_NEET_(%)_(2014)',
#        'Proportion_of_the_working-age_population_who_claim_out-of-work_benefits_(%)_(May-2016)',
#        '%_working-age_with_a_disability_(2015)',
#        'Proportion_of_working_age_people_with_no_qualifications_(%)_2015',
#        'Proportion_of_working_age_with_degree_or_equivalent_and_above_(%)_2015',
#        'Gross_Annual_Pay,_(2016)', 'Gross_Annual_Pay_-_Male_(2016)',
#        'Gross_Annual_Pay_-_Female_(2016)',
#        'Modelled_Household_median_income_estimates_2012/13',
#        '%_adults_that_volunteered_in_past_12_months_(2010/11_to_2012/13)',
#        'Number_of_jobs_by_workplace_(2014)',
#        '%_of_employment_that_is_in_public_sector_(2014)', 'Jobs_Density,_2015',
#        'Number_of_active_businesses,_2015',
#        'Two-year_business_survival_rates_(started_in_2013)',
#        'Crime_rates_per_thousand_population_2014/15',
#        'Fires_per_thousand_population_(2014)',
#        'Ambulance_incidents_per_hundred_population_(2014)',
#        'Median_House_Price,_2015',
#        'Average_Band_D_Council_Tax_charge_(£),_2015/16',
#        'New_Homes_(net)_2015/16_(provisional)',
#        'Homes_Owned_outright,_(2014)_%',
#        'Being_bought_with_mortgage_or_loan,_(2014)_%',
#        'Rented_from_Local_Authority_or_Housing_Association,_(2014)_%',
#        'Rented_from_Private_landlord,_(2014)_%',
#        '%_of_area_that_is_Greenspace,_2005', 'Total_carbon_emissions_(2014)',
#        'Household_Waste_Recycling_Rate,_2014/15',
#        'Number_of_cars,_(2011_Census)',
#        'Number_of_cars_per_household,_(2011_Census)',
#        '%_of_adults_who_cycle_at_least_once_per_month,_2014/15',
#        'Average_Public_Transport_Accessibility_score,_2014',
#        'Achievement_of_5_or_more_A*-_C_grades_at_GCSE_or_equivalent_including_English_and_Maths,_2013/14',
#        'Rates_of_Children_Looked_After_(2016)',
#        '%_of_pupils_whose_first_language_is_not_English_(2015)',
#        '%_children_living_in_out-of-work_households_(2015)',
#        'Male_life_expectancy,_(2012-14)', 'Female_life_expectancy,_(2012-14)',
#        'Teenage_conception_rate_(2014)',
#        'Life_satisfaction_score_2011-14_(out_of_10)',
#        'Worthwhileness_score_2011-14_(out_of_10)',
#        'Happiness_score_2011-14_(out_of_10)',
#        'Anxiety_score_2011-14_(out_of_10)',
#        'Childhood_Obesity_Prevalance_(%)_2015/16',
#        'People_aged_17+_with_diabetes_(%)',
#        'Mortality_rate_from_causes_considered_preventable_2012/14',
#        'Political_control_in_council',
#        'Proportion_of_seats_won_by_Conservatives_in_2014_election',
#        'Proportion_of_seats_won_by_Labour_in_2014_election',
#        'Proportion_of_seats_won_by_Lib_Dems_in_2014_election',
#        'Turnout_at_2014_local_elections'],
#       dtype='object')

# %%
crime_lon
# Out:
#                  Area_name  Crime_rates_per_thousand_population_2014/15  \
# 0           City of London                                          NaN
# 1     Barking and Dagenham                                         83.4
# 2                   Barnet                                         62.7
# 3                   Bexley                                         51.8
# 4                    Brent                                         78.8
# 5                  Bromley                                         64.1
# 6                   Camden                                        123.5
# 7                  Croydon                                         77.0
# 8                   Ealing                                         75.5
# 9                  Enfield                                         69.4
# 10               Greenwich                                         79.4
# 11                 Hackney                                         99.6
# 12  Hammersmith and Fulham                                        113.2
# 13                Haringey                                         90.2
# 14                  Harrow                                         50.4
# 15                Havering                                         62.9
# 16              Hillingdon                                         76.6
# 17                Hounslow                                         79.2
# 18               Islington                                        121.2
# 19  Kensington and Chelsea                                        120.9
# 20    Kingston upon Thames                                         58.5
# 21                 Lambeth                                        104.6
# 22                Lewisham                                         77.0
# 23                  Merton                                         59.7
# 24                  Newham                                         90.8
# 25               Redbridge                                         69.7
# 26    Richmond upon Thames                                         56.3
# 27               Southwark                                        100.6
# 28                  Sutton                                         55.9
# 29           Tower Hamlets                                         99.9
# 30          Waltham Forest                                         78.0
# 31              Wandsworth                                         72.6
# 32             Westminster                                        212.4
# 33            Inner London                                        106.4
# 34            Outer London                                         69.4
# 35                  London                                         84.0
# 36                 England                                         65.7
# 37          United Kingdom                                          NaN
#
#     Median_House_Price,_2015
# 0                   799999.0
# 1                   243500.0
# 2                   445000.0
# 3                   275000.0
# 4                   407250.0
# 5                   374975.0
# 6                   700000.0
# 7                   300000.0
# 8                   430000.0
# 9                   320000.0
# 10                  340000.0
# 11                  485000.0
# 12                  730000.0
# 13                  432500.0
# 14                  396150.0
# 15                  287500.0
# 16                  350000.0
# 17                  355000.0
# 18                  583000.0
# 19                 1200000.0
# 20                  410000.0
# 21                  450000.0
# 22                  352000.0
# 23                  415000.0
# 24                  305000.0
# 25                  345000.0
# 26                  575000.0
# 27                  475000.0
# 28                  320000.0
# 29                  415000.0
# 30                  366569.0
# 31                  557000.0
# 32                  920000.0
# 33                  495000.0
# 34                  350000.0
# 35                  399950.0
# 36                  209995.0
# 37                       NaN

# %%
LDN = crime_lon.rename({"Crime_rates_per_thousand_population_2014/15":"arrest/1000"},axis=1)

# %%
LDN = LDN.set_index("Area_name")
LDN = LDN.dropna(axis=0, inplace=False)
LDN
# Out:
#                         arrest/1000  Median_House_Price,_2015
# Area_name
# Barking and Dagenham           83.4                  243500.0
# Barnet                         62.7                  445000.0
# Bexley                         51.8                  275000.0
# Brent                          78.8                  407250.0
# Bromley                        64.1                  374975.0
# Camden                        123.5                  700000.0
# Croydon                        77.0                  300000.0
# Ealing                         75.5                  430000.0
# Enfield                        69.4                  320000.0
# Greenwich                      79.4                  340000.0
# Hackney                        99.6                  485000.0
# Hammersmith and Fulham        113.2                  730000.0
# Haringey                       90.2                  432500.0
# Harrow                         50.4                  396150.0
# Havering                       62.9                  287500.0
# Hillingdon                     76.6                  350000.0
# Hounslow                       79.2                  355000.0
# Islington                     121.2                  583000.0
# Kensington and Chelsea        120.9                 1200000.0
# Kingston upon Thames           58.5                  410000.0
# Lambeth                       104.6                  450000.0
# Lewisham                       77.0                  352000.0
# Merton                         59.7                  415000.0
# Newham                         90.8                  305000.0
# Redbridge                      69.7                  345000.0
# Richmond upon Thames           56.3                  575000.0
# Southwark                     100.6                  475000.0
# Sutton                         55.9                  320000.0
# Tower Hamlets                  99.9                  415000.0
# Waltham Forest                 78.0                  366569.0
# Wandsworth                     72.6                  557000.0
# Westminster                   212.4                  920000.0
# Inner London                  106.4                  495000.0
# Outer London                   69.4                  350000.0
# London                         84.0                  399950.0
# England                        65.7                  209995.0

# %%
LDN.shape
# Out:
# (36, 2)

# %% [markdown]
# ## COMPARISON

# %% [markdown]
# ### Cleaned Data Frames

# %%
NYC
# Out:
#                arrest_per_thousand  MEDIAN SALE PRICE
# BOROUGH
# Bronx                     9.517404       5.123333e+05
# Brooklyn                  6.262945       8.871667e+05
# Manhatton                 9.031504       4.346667e+06
# Queens                    5.285755       7.546667e+05
# Staton Island             5.344904       5.422230e+05

# %%
LDN.head()
# Out:
#                       arrest/1000  Median_House_Price,_2015
# Area_name
# Barking and Dagenham         83.4                  243500.0
# Barnet                       62.7                  445000.0
# Bexley                       51.8                  275000.0
# Brent                        78.8                  407250.0
# Bromley                      64.1                  374975.0

# %% [markdown]
# ## VISULAISATION

# %%
import numpy as np
# %matplotlib inline 

import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.style.use('ggplot') # optional: for ggplot-like style

# check for latest version of Matplotlib
print ('Matplotlib version: ', mpl.__version__) # >= 2.0.0
# Out:
# Matplotlib version:  3.1.0

# %%
# install seaborn
# !conda install -c anaconda seaborn --yes

# import library
import seaborn as sns

print('Seaborn installed and imported!')
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.7.11
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - seaborn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2019.6.16          |           py36_1         156 KB  anaconda
#
# The following packages will be UPDATED:
#
#     certifi: 2019.6.16-py36_1  conda-forge --> 2019.6.16-py36_1  anaconda
#     openssl: 1.0.2r-h14c3975_0 conda-forge --> 1.0.2s-h7b6447c_0 anaconda
#
#
# Downloading and Extracting Packages
# certifi-2019.6.16    | 156 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Seaborn installed and imported!

# %%
print("The column names of NYC and London respectively are: ")
print(NYC.columns)
print(LDN.columns)
# Out:
# The column names of NYC and London respectively are:
# Index(['arrest_per_thousand', 'MEDIAN SALE PRICE'], dtype='object')
# Index(['arrest/1000', 'Median_House_Price,_2015'], dtype='object')

# %%
import seaborn as sns
plt.figure(figsize=(15, 10))
sns.set(font_scale=1.5)
sns.set_style('whitegrid')

NYCreg = sns.regplot(x='arrest_per_thousand', y='MEDIAN SALE PRICE', data=NYC, color='green', marker='+', scatter_kws={'s': 200})

NYCreg.set(xlabel='Arrests per Thousand, 2014', ylabel='Median House Sale Price')
NYCreg.set_title('Comparison of Arrest rate and House PRices in NYC')
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0.5, 1.0, 'Comparison of Arrest rate and House PRices in NYC')

# %%
plt.figure(figsize=(15, 10))
sns.set(font_scale=1.5)
sns.set_style('whitegrid')

LDNreg = sns.regplot(x='arrest/1000', y='Median_House_Price,_2015', data=LDN, color='blue', marker='+', scatter_kws={'s': 200})

LDNreg.set(xlabel='Crime rate per Thousand', ylabel='Median House Sale Prices') 
LDNreg.set_title('Comparison between Crime rate and Hosue price in London')
# Out:
# Text(0.5, 1.0, 'Comparison between Crime rate and Hosue price in London')

# %%
NYC["arrest_per_thousand"].plot(kind='bar', figsize=(10, 6))

plt.xlabel('Location')
plt.ylabel('Nunber of Arrests in NYC')
plt.title('Number of arrests in each Borogh in NYC')

plt.show()

# %%
NYC["MEDIAN SALE PRICE"].plot(kind='bar', figsize=(10, 6))

plt.xlabel('Location')
plt.ylabel('House prices in NYC')
plt.title('House Prices in each Borogh in NYC')

plt.show()

# %%
LDN.columns
# Out:
# Index(['arrest/1000', 'Median_House_Price,_2015'], dtype='object')

# %%
LDN["arrest/1000"].plot(kind='bar', figsize=(10, 6))

plt.xlabel('Location')
plt.ylabel('Crime rates in London')
plt.title('Crime rates in each Borogh in London')

plt.show()

# %%
LDN["Median_House_Price,_2015"].plot(kind='bar', figsize=(10, 6))

plt.xlabel('Location')
plt.ylabel('House prices')
plt.title('House Prices in each Borogh in NYC')

plt.show()

# %%
LDN.describe()
# Out:
#        arrest/1000  Median_House_Price,_2015
# count    36.000000              3.600000e+01
# mean     84.480556              4.448719e+05
# std      29.811664              1.922015e+05
# min      50.400000              2.099950e+05
# 25%      65.300000              3.437500e+05
# 50%      77.500000              4.036000e+05
# 75%      99.675000              4.775000e+05
# max     212.400000              1.200000e+06

# %%
NYC.describe()
# Out:
#        arrest_per_thousand  MEDIAN SALE PRICE
# count             5.000000       5.000000e+00
# mean              7.088502       1.408611e+06
# std               2.040000       1.649671e+06
# min               5.285755       5.123333e+05
# 25%               5.344904       5.422230e+05
# 50%               6.262945       7.546667e+05
# 75%               9.031504       8.871667e+05
# max               9.517404       4.346667e+06

# %%
NYC["MEDIAN SALE PRICE"] = NYC["MEDIAN SALE PRICE"]/1000000
NYC
# Out:
#                arrest_per_thousand  MEDIAN SALE PRICE
# BOROUGH
# Bronx                     9.517404           0.512333
# Brooklyn                  6.262945           0.887167
# Manhatton                 9.031504           4.346667
# Queens                    5.285755           0.754667
# Staton Island             5.344904           0.542223

# %%
LDN["Median_House_Price,_2015"] = LDN["Median_House_Price,_2015"]/10000
LDN.head()
# Out:
#                       arrest/1000  Median_House_Price,_2015
# Area_name
# Barking and Dagenham         83.4                   24.3500
# Barnet                       62.7                   44.5000
# Bexley                       51.8                   27.5000
# Brent                        78.8                   40.7250
# Bromley                      64.1                   37.4975

# %%
LDN.plot()

# %%
NYC.plot()

# %% [markdown]
# ## FOURSQUARE

# %%
import requests

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

from IPython.display import Image 
from IPython.core.display import HTML 
    
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.7.11
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2019.6.16          |           py36_1         149 KB  conda-forge
#
# The following packages will be UPDATED:
#
#     certifi: 2019.6.16-py36_1  anaconda --> 2019.6.16-py36_1  conda-forge
#
# The following packages will be DOWNGRADED:
#
#     openssl: 1.0.2s-h7b6447c_0 anaconda --> 1.0.2r-h14c3975_0 conda-forge
#
#
# Downloading and Extracting Packages
# certifi-2019.6.16    | 149 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.7.11
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.
#
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = '0E342GFWIDEXUXNAD1CZBA0OAZADAYSFVPL0L1SRBUHRIOX2' # your Foursquare ID
CLIENT_SECRET = '1SRJI3ZOEKVNPXA4T4QXQONHSCWMMNL45IOO3YL2F2B5OLYB' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 0E342GFWIDEXUXNAD1CZBA0OAZADAYSFVPL0L1SRBUHRIOX2
# CLIENT_SECRET:1SRJI3ZOEKVNPXA4T4QXQONHSCWMMNL45IOO3YL2F2B5OLYB

# %% [markdown]
# Coffee Shops around Westminster, UK

# %%
latitude = 51.49
longitude = -0.13

search_query = 'Coffee Shop'
radius = 500
LIMIT = 500

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=0E342GFWIDEXUXNAD1CZBA0OAZADAYSFVPL0L1SRBUHRIOX2&client_secret=1SRJI3ZOEKVNPXA4T4QXQONHSCWMMNL45IOO3YL2F2B5OLYB&ll=51.49,-0.13&v=20180604&query=Coffee Shop&radius=500&limit=500'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d5c31029241f8002539bbc5'},
#  'response': {'venues': [{'id': '53a1495d498e8d709a41b0a6',
#     'name': 'pimlico village coffee shop',
#     'location': {'lat': 51.488846188177064,
#      'lng': -0.13461200840747686,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.488846188177064,
#        'lng': -0.13461200840747686}],
#      'distance': 344,
#      'cc': 'GB',
#      'city': 'SW1',
#      'country': 'United Kingdom',
#      'formattedAddress': ['SW1', 'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566322946',
#     'hasPerk': False},
#    {'id': '4ad4709ff964a520e0e720e3',
#     'name': 'Relish Sandwich Shop',
#     'location': {'address': '8 John Islip St',
#      'lat': 51.489677253806114,
#      'lng': -0.13029545295020328,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.489677253806114,
#        'lng': -0.13029545295020328}],
#      'distance': 41,
#      'postalCode': 'SW1P 4PY',
#      'cc': 'GB',
#      'neighborhood': 'Millbank, London, Greater London',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['8 John Islip St',
#       'London',
#       'Greater London',
#       'SW1P 4PY',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566322946',
#     'hasPerk': False},
#    {'id': '4c5288329d642d7faee759df',
#     'name': 'Pimlico Village',
#     'location': {'address': '5 Lupus St.',
#      'crossStreet': 'at Aylesford St.',
#      'lat': 51.488893614407395,
#      'lng': -0.1344234455194924,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.488893614407395,
#        'lng': -0.1344234455194924}],
#      'distance': 330,
#      'postalCode': 'SW1V 3AS',
#      'cc': 'GB',
#      'city': 'Pimlico',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['5 Lupus St. (at Aylesford St.)',
#       'Pimlico',
#       'Greater London',
#       'SW1V 3AS',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566322946',
#     'hasPerk': False},
#    {'id': '4f367079e4b0ea2d7cc64038',
#     'name': 'Gallery Shop - Tate Britain',
#     'location': {'address': 'Millbank',
#      'lat': 51.49091857269487,
#      'lng': -0.12755384530298305,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.49091857269487,
#        'lng': -0.12755384530298305}],
#      'distance': 197,
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Millbank',
#       'London',
#       'Greater London',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d128951735',
#       'name': 'Gift Shop',
#       'pluralName': 'Gift Shops',
#       'shortName': 'Gift Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/giftshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566322946',
#     'hasPerk': False},
#    {'id': '590dfae625fb7b50fb52ea28',
#     'name': "Lalo's Barber Shop",
#     'location': {'address': '12a Vauxhall Bridge Road',
#      'lat': 51.48963,
#      'lng': -0.131181,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.48963,
#        'lng': -0.131181}],
#      'distance': 91,
#      'postalCode': 'SW1V 2SD',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['12a Vauxhall Bridge Road',
#       'London',
#       'Greater London',
#       'SW1V 2SD',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d110951735',
#       'name': 'Salon / Barbershop',
#       'pluralName': 'Salons / Barbershops',
#       'shortName': 'Salon / Barbershop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566322946',
#     'hasPerk': False},
#    {'id': '56ff918f498e2210eaa6791c',
#     'name': 'Costa Coffee',
#     'location': {'address': 'Horseferry Road',
#      'lat': 51.49490697641138,
#      'lng': -0.12947528766284455,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.49490697641138,
#        'lng': -0.12947528766284455}],
#      'distance': 547,
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Horseferry Road',
#       'London',
#       'Greater London',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566322946',
#     'hasPerk': False},
#    {'id': '4d1c5c8efd7bb60cd6449de1',
#     'name': "Robbie's Gents Barber Shop",
#     'location': {'address': '36 Page Street',
#      'lat': 51.49399096429673,
#      'lng': -0.1310954536454909,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.49399096429673,
#        'lng': -0.1310954536454909}],
#      'distance': 450,
#      'postalCode': 'SW1',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['36 Page Street',
#       'London',
#       'Greater London',
#       ' SW1',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d110951735',
#       'name': 'Salon / Barbershop',
#       'pluralName': 'Salons / Barbershops',
#       'shortName': 'Salon / Barbershop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566322946',
#     'hasPerk': False},
#    {'id': '4c343b51a0ced13ac6db176e',
#     'name': 'Brunswick House Cafe',
#     'location': {'address': '30 Wandsworth Rd.',
#      'lat': 51.48486584038857,
#      'lng': -0.12622374886072407,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.48486584038857,
#        'lng': -0.12622374886072407}],
#      'distance': 628,
#      'postalCode': 'SW8 2LG',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['30 Wandsworth Rd.',
#       'London',
#       'Greater London',
#       'SW8 2LG',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566322946',
#     'hasPerk': False},
#    {'id': '4c517eda250dd13aba94517d',
#     'name': 'Ravello Coffee Co',
#     'location': {'address': 'Dean Bradley St.',
#      'lat': 51.49498546732257,
#      'lng': -0.12694290185711385,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.49498546732257,
#        'lng': -0.12694290185711385}],
#      'distance': 594,
#      'postalCode': 'SW1',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Dean Bradley St.',
#       'London',
#       'Greater London',
#       ' SW1',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566322946',
#     'hasPerk': False},
#    {'id': '5d00648d561a37002bc7e1dd',
#     'name': 'DPD Parcel Shop Location - Parliament News',
#     'location': {'address': '56 Horseferry Road Westminster',
#      'lat': 51.4949741,
#      'lng': -0.1275664,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.4949741,
#        'lng': -0.1275664}],
#      'distance': 578,
#      'postalCode': 'SW1P 2AF',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['56 Horseferry Road Westminster',
#       'London',
#       'Greater London',
#       'SW1P 2AF',
#       'United Kingdom']},
#     'categories': [{'id': '5453de49498eade8af355881',
#       'name': 'Business Service',
#       'pluralName': 'Business Services',
#       'shortName': 'Business Services',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566322946',
#     'hasPerk': False},
#    {'id': '4e79a686e4cdb158f1ff981d',
#     'name': "Cafe L'Express",
#     'location': {'address': '48 Horseferry Road',
#      'lat': 51.49475746839587,
#      'lng': -0.12908935546875,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.49475746839587,
#        'lng': -0.12908935546875}],
#      'distance': 533,
#      'postalCode': 'SW1P 2AF',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['48 Horseferry Road',
#       'London',
#       'Greater London',
#       'SW1P 2AF',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566322946',
#     'hasPerk': False},
#    {'id': '54b29516498e42d1e0ffd601',
#     'name': 'Monmouth coffee',
#     'location': {'lat': 51.4840565059017,
#      'lng': -0.12671017962931844,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.4840565059017,
#        'lng': -0.12671017962931844}],
#      'distance': 699,
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566322946',
#     'hasPerk': False},
#    {'id': '4c863b6bd8086dcb0c4f9852',
#     'name': 'Westminster Book Shop',
#     'location': {'lat': 51.49537154999072,
#      'lng': -0.12698105835526527,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.49537154999072,
#        'lng': -0.12698105835526527}],
#      'distance': 633,
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d114951735',
#       'name': 'Bookstore',
#       'pluralName': 'Bookstores',
#       'shortName': 'Bookstore',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566322946',
#     'hasPerk': False},
#    {'id': '4b2e1fabf964a520dedc24e3',
#     'name': 'Express Coffee Co',
#     'location': {'address': '40 Strutton Ground',
#      'lat': 51.49650804068179,
#      'lng': -0.1337003739040803,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.49650804068179,
#        'lng': -0.1337003739040803}],
#      'distance': 768,
#      'postalCode': 'SW1P 2HR',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['40 Strutton Ground',
#       'London',
#       'Greater London',
#       'SW1P 2HR',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1dc931735',
#       'name': 'Tea Room',
#       'pluralName': 'Tea Rooms',
#       'shortName': 'Tea Room',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tearoom_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566322946',
#     'hasPerk': False},
#    {'id': '4b068caff964a52005ed22e3',
#     'name': 'Starbucks',
#     'location': {'address': '35 Horseferry Rd',
#      'lat': 51.494729,
#      'lng': -0.130424,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.494729,
#        'lng': -0.130424}],
#      'distance': 527,
#      'postalCode': 'SW1P 2AA',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['35 Horseferry Rd',
#       'London',
#       'Greater London',
#       'SW1P 2AA',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566322946',
#     'hasPerk': False},
#    {'id': '4c7264dcad69b60c7e4483b9',
#     'name': "Gianni's",
#     'location': {'address': '48 Horseferry Rd',
#      'lat': 51.49486063887886,
#      'lng': -0.12713937109640466,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.49486063887886,
#        'lng': -0.12713937109640466}],
#      'distance': 576,
#      'postalCode': 'SW1P 2AF',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['48 Horseferry Rd',
#       'London',
#       'Greater London',
#       'SW1P 2AF',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566322946',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                          id                         name  \
# 0  53a1495d498e8d709a41b0a6  pimlico village coffee shop
# 1  4ad4709ff964a520e0e720e3         Relish Sandwich Shop
# 2  4c5288329d642d7faee759df              Pimlico Village
# 3  4f367079e4b0ea2d7cc64038  Gallery Shop - Tate Britain
# 4  590dfae625fb7b50fb52ea28           Lalo's Barber Shop
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1566322946    False
# 1  [{'id': '4bf58dd8d48988d1c5941735', 'name': 'S...  v-1566322946    False
# 2  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1566322946    False
# 3  [{'id': '4bf58dd8d48988d128951735', 'name': 'G...  v-1566322946    False
# 4  [{'id': '4bf58dd8d48988d110951735', 'name': 'S...  v-1566322946    False
#
#    location.lat  location.lng  \
# 0     51.488846     -0.134612
# 1     51.489677     -0.130295
# 2     51.488894     -0.134423
# 3     51.490919     -0.127554
# 4     51.489630     -0.131181
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 51.48884618817706...                344
# 1  [{'label': 'display', 'lat': 51.48967725380611...                 41
# 2  [{'label': 'display', 'lat': 51.48889361440739...                330
# 3  [{'label': 'display', 'lat': 51.49091857269487...                197
# 4  [{'label': 'display', 'lat': 51.48963, 'lng': ...                 91
#
#   location.cc location.city location.country  \
# 0          GB           SW1   United Kingdom
# 1          GB        London   United Kingdom
# 2          GB       Pimlico   United Kingdom
# 3          GB        London   United Kingdom
# 4          GB        London   United Kingdom
#
#                            location.formattedAddress  \
# 0                              [SW1, United Kingdom]
# 1  [8 John Islip St, London, Greater London, SW1P...
# 2  [5 Lupus St. (at Aylesford St.), Pimlico, Grea...
# 3  [Millbank, London, Greater London, United King...
# 4  [12a Vauxhall Bridge Road, London, Greater Lon...
#
#            location.address location.postalCode  \
# 0                       NaN                 NaN
# 1           8 John Islip St            SW1P 4PY
# 2               5 Lupus St.            SW1V 3AS
# 3                  Millbank                 NaN
# 4  12a Vauxhall Bridge Road            SW1V 2SD
#
#               location.neighborhood  location.state location.crossStreet
# 0                               NaN             NaN                  NaN
# 1  Millbank, London, Greater London  Greater London                  NaN
# 2                               NaN  Greater London     at Aylesford St.
# 3                               NaN  Greater London                  NaN
# 4                               NaN  Greater London                  NaN

# %%
dataframe.shape
# Out:
# (16, 18)

# %% [markdown]
# Coffee Shops aroumd

# %% [markdown]
# Coffee Shops around the Bronx, USA

# %%
latitude = 40.84
longitude = -73.86

search_query = 'Coffee Shop'
radius = 500
LIMIT = 500

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d5c31038afbe0002e59d4f8'},
#  'response': {'venues': [{'id': '4e4e297abd4101d0d7a3af75',
#     'name': "John's Donut Coffee Shop",
#     'location': {'address': '1786 Westchester Ave',
#      'lat': 40.839603156980544,
#      'lng': -73.86665556669777,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.839603156980544,
#        'lng': -73.86665556669777}],
#      'distance': 562,
#      'postalCode': '10472',
#      'cc': 'US',
#      'city': 'Bronx',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1786 Westchester Ave',
#       'Bronx, NY 10472',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d148941735',
#       'name': 'Donut Shop',
#       'pluralName': 'Donut Shops',
#       'shortName': 'Donuts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566322947',
#     'hasPerk': False},
#    {'id': '4df7674c1838c789e8b94b1a',
#     'name': 'M & V Coffee Shop',
#     'location': {'address': 'Archer st',
#      'lat': 40.837635541857736,
#      'lng': -73.86701734920317,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.837635541857736,
#        'lng': -73.86701734920317}],
#      'distance': 646,
#      'postalCode': '10460',
#      'cc': 'US',
#      'city': 'Bronx',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Archer st', 'Bronx, NY 10460', 'United States']},
#     'categories': [],
#     'referralId': 'v-1566322947',
#     'hasPerk': False},
#    {'id': '4adb9b03f964a520552921e3',
#     'name': "Ellie's Diner",
#     'location': {'address': '58 Metropolitan Oval',
#      'crossStreet': 'Unionport Rd',
#      'lat': 40.83788039213797,
#      'lng': -73.86013179887586,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.83788039213797,
#        'lng': -73.86013179887586}],
#      'distance': 236,
#      'postalCode': '10462',
#      'cc': 'US',
#      'city': 'Bronx',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['58 Metropolitan Oval (Unionport Rd)',
#       'Bronx, NY 10462',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '305994',
#      'url': 'https://www.seamless.com/menu/ellies-diner-58-metropolitan-oval-bronx/305994?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=305994',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1566322947',
#     'hasPerk': False},
#    {'id': '4b3d1afef964a520148e25e3',
#     'name': 'Beato Barber Shop',
#     'location': {'address': '1665 Unionport Rd',
#      'lat': 40.83964133533965,
#      'lng': -73.85801818135275,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.83964133533965,
#        'lng': -73.85801818135275}],
#      'distance': 171,
#      'postalCode': '10462',
#      'cc': 'US',
#      'city': 'Bronx',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1665 Unionport Rd',
#       'Bronx, NY 10462',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110951735',
#       'name': 'Salon / Barbershop',
#       'pluralName': 'Salons / Barbershops',
#       'shortName': 'Salon / Barbershop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566322947',
#     'hasPerk': False},
#    {'id': '52b61ed911d22f848327f2d4',
#     'name': 'Beato Barber Shop',
#     'location': {'lat': 40.83966080529721,
#      'lng': -73.85803085040365,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.83966080529721,
#        'lng': -73.85803085040365}],
#      'distance': 170,
#      'cc': 'US',
#      'city': 'Bronx',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Bronx, NY', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110951735',
#       'name': 'Salon / Barbershop',
#       'pluralName': 'Salons / Barbershops',
#       'shortName': 'Salon / Barbershop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566322947',
#     'hasPerk': False},
#    {'id': '4e627df5c65b2dc89fa8354f',
#     'name': 'Shop Smart',
#     'location': {'lat': 40.83967759514596,
#      'lng': -73.8579840724008,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.83967759514596,
#        'lng': -73.8579840724008}],
#      'distance': 173,
#      'cc': 'US',
#      'state': 'New York',
#      'country': 'United States',
#      'formattedAddress': ['New York', 'United States']},
#     'categories': [{'id': '4d954b0ea243a5684a65b473',
#       'name': 'Convenience Store',
#       'pluralName': 'Convenience Stores',
#       'shortName': 'Convenience Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566322947',
#     'hasPerk': False},
#    {'id': '4f1f1fe1e4b01d27e7114c0e',
#     'name': 'The Barber Shop!',
#     'location': {'lat': 40.8385184,
#      'lng': -73.8586263,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.8385184,
#        'lng': -73.8586263}],
#      'distance': 201,
#      'postalCode': '10462',
#      'cc': 'US',
#      'city': 'Bronx',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Bronx, NY 10462', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110951735',
#       'name': 'Salon / Barbershop',
#       'pluralName': 'Salons / Barbershops',
#       'shortName': 'Salon / Barbershop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566322947',
#     'hasPerk': False},
#    {'id': '4b858bdaf964a520b76431e3',
#     'name': 'Barber shop',
#     'location': {'address': 'E. Tremont ave.',
#      'crossStreet': 'Unionport road',
#      'lat': 40.841513,
#      'lng': -73.861497,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.841513,
#        'lng': -73.861497}],
#      'distance': 210,
#      'postalCode': '10462',
#      'cc': 'US',
#      'city': 'Bronx',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['E. Tremont ave. (Unionport road)',
#       'Bronx, NY 10462',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110951735',
#       'name': 'Salon / Barbershop',
#       'pluralName': 'Salons / Barbershops',
#       'shortName': 'Salon / Barbershop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566322947',
#     'hasPerk': False},
#    {'id': '4b217496f964a5201c3c24e3',
#     'name': 'Starbucks',
#     'location': {'address': '1385 Metropolitan Ave',
#      'crossStreet': 'at Wood Ave',
#      'lat': 40.835396,
#      'lng': -73.86151,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.835396,
#        'lng': -73.86151}],
#      'distance': 528,
#      'postalCode': '10462',
#      'cc': 'US',
#      'city': 'Bronx',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1385 Metropolitan Ave (at Wood Ave)',
#       'Bronx, NY 10462',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566322947',
#     'hasPerk': False},
#    {'id': '4c7e9acfd51ea1438429589f',
#     'name': 'Energy Barber Shop',
#     'location': {'lat': 40.83955215191945,
#      'lng': -73.86368563400656,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.83955215191945,
#        'lng': -73.86368563400656}],
#      'distance': 314,
#      'postalCode': '10462',
#      'cc': 'US',
#      'city': 'Bronx',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Bronx, NY 10462', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110951735',
#       'name': 'Salon / Barbershop',
#       'pluralName': 'Salons / Barbershops',
#       'shortName': 'Salon / Barbershop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566322947',
#     'hasPerk': False},
#    {'id': '4d2c763a55a8b60c0037f0c0',
#     'name': 'Rocco Auto Shop',
#     'location': {'address': '1571 Bronxdale Ave',
#      'lat': 40.84379271964628,
#      'lng': -73.85603149775606,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.84379271964628,
#        'lng': -73.85603149775606}],
#      'distance': 538,
#      'postalCode': '10462',
#      'cc': 'US',
#      'city': 'Bronx',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1571 Bronxdale Ave',
#       'Bronx, NY 10462',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124951735',
#       'name': 'Automotive Shop',
#       'pluralName': 'Automotive Shops',
#       'shortName': 'Automotive',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/automotive_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566322947',
#     'hasPerk': False},
#    {'id': '4c0a8854009a0f478d89e9bf',
#     'name': 'David G Barber Shop',
#     'location': {'address': 'unionport and east tremont',
#      'lat': 40.84116767478459,
#      'lng': -73.86401395995391,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.84116767478459,
#        'lng': -73.86401395995391}],
#      'distance': 362,
#      'postalCode': '10462',
#      'cc': 'US',
#      'city': 'Bronx',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['unionport and east tremont',
#       'Bronx, NY 10462',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110951735',
#       'name': 'Salon / Barbershop',
#       'pluralName': 'Salons / Barbershops',
#       'shortName': 'Salon / Barbershop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566322947',
#     'hasPerk': False},
#    {'id': '52004f14498e419b34ab3567',
#     'name': 'Grocery & Smoke Shop',
#     'location': {'lat': 40.835866,
#      'lng': -73.85602,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.835866,
#        'lng': -73.85602}],
#      'distance': 569,
#      'cc': 'US',
#      'city': 'Bronx',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Bronx, NY', 'United States']},
#     'categories': [{'id': '4d954b0ea243a5684a65b473',
#       'name': 'Convenience Store',
#       'pluralName': 'Convenience Stores',
#       'shortName': 'Convenience Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566322947',
#     'hasPerk': False},
#    {'id': '536547b3498e4062318900ed',
#     'name': 'Archer Ave Barber Shop',
#     'location': {'address': 'Archer Avenue',
#      'crossStreet': 'Beach Ave',
#      'lat': 40.8379,
#      'lng': -73.867,
#      'labeledLatLngs': [{'label': 'display', 'lat': 40.8379, 'lng': -73.867}],
#      'distance': 634,
#      'cc': 'US',
#      'city': 'Bronx',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Archer Avenue (Beach Ave)',
#       'Bronx, NY',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110951735',
#       'name': 'Salon / Barbershop',
#       'pluralName': 'Salons / Barbershops',
#       'shortName': 'Salon / Barbershop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566322947',
#     'hasPerk': False},
#    {'id': '4d9895f2c19fb60c6478b165',
#     'name': 'NutriShop',
#     'location': {'lat': 40.843371467977406,
#      'lng': -73.85680947902385,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.843371467977406,
#        'lng': -73.85680947902385}],
#      'distance': 461,
#      'cc': 'US',
#      'state': 'New York',
#      'country': 'United States',
#      'formattedAddress': ['New York', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'shortName': 'Pharmacy',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566322947',
#     'hasPerk': False},
#    {'id': '4c262fbfc11dc9b66c732824',
#     'name': 'Phase One',
#     'location': {'address': '2001 Westchester Ave',
#      'crossStreet': 'at Pugsley Ave',
#      'lat': 40.83364007313768,
#      'lng': -73.8575683291721,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.83364007313768,
#        'lng': -73.8575683291721}],
#      'distance': 737,
#      'postalCode': '10462',
#      'cc': 'US',
#      'city': 'Bronx',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['2001 Westchester Ave (at Pugsley Ave)',
#       'Bronx, NY 10462',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110951735',
#       'name': 'Salon / Barbershop',
#       'pluralName': 'Salons / Barbershops',
#       'shortName': 'Salon / Barbershop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566322947',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                          id                      name  \
# 0  4e4e297abd4101d0d7a3af75  John's Donut Coffee Shop
# 1  4df7674c1838c789e8b94b1a         M & V Coffee Shop
# 2  4adb9b03f964a520552921e3             Ellie's Diner
# 3  4b3d1afef964a520148e25e3         Beato Barber Shop
# 4  52b61ed911d22f848327f2d4         Beato Barber Shop
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d148941735', 'name': 'D...  v-1566322947    False
# 1                                                 []  v-1566322947    False
# 2  [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...  v-1566322947    False
# 3  [{'id': '4bf58dd8d48988d110951735', 'name': 'S...  v-1566322947    False
# 4  [{'id': '4bf58dd8d48988d110951735', 'name': 'S...  v-1566322947    False
#
#        location.address  location.lat  location.lng  \
# 0  1786 Westchester Ave     40.839603    -73.866656
# 1             Archer st     40.837636    -73.867017
# 2  58 Metropolitan Oval     40.837880    -73.860132
# 3     1665 Unionport Rd     40.839641    -73.858018
# 4                   NaN     40.839661    -73.858031
#
#                              location.labeledLatLngs  location.distance  ...  \
# 0  [{'label': 'display', 'lat': 40.83960315698054...                562  ...
# 1  [{'label': 'display', 'lat': 40.83763554185773...                646  ...
# 2  [{'label': 'display', 'lat': 40.83788039213797...                236  ...
# 3  [{'label': 'display', 'lat': 40.83964133533965...                171  ...
# 4  [{'label': 'display', 'lat': 40.83966080529721...                170  ...
#
#   location.state location.country  \
# 0             NY    United States
# 1             NY    United States
# 2             NY    United States
# 3             NY    United States
# 4             NY    United States
#
#                            location.formattedAddress location.crossStreet  \
# 0  [1786 Westchester Ave, Bronx, NY 10472, United...                  NaN
# 1        [Archer st, Bronx, NY 10460, United States]                  NaN
# 2  [58 Metropolitan Oval (Unionport Rd), Bronx, N...         Unionport Rd
# 3  [1665 Unionport Rd, Bronx, NY 10462, United St...                  NaN
# 4                         [Bronx, NY, United States]                  NaN
#
#   delivery.id                                       delivery.url  \
# 0         NaN                                                NaN
# 1         NaN                                                NaN
# 2      305994  https://www.seamless.com/menu/ellies-diner-58-...
# 3         NaN                                                NaN
# 4         NaN                                                NaN
#
#   delivery.provider.name             delivery.provider.icon.prefix  \
# 0                    NaN                                       NaN
# 1                    NaN                                       NaN
# 2               seamless  https://fastly.4sqi.net/img/general/cap/
# 3                    NaN                                       NaN
# 4                    NaN                                       NaN
#
#   delivery.provider.icon.sizes               delivery.provider.icon.name
# 0                          NaN                                       NaN
# 1                          NaN                                       NaN
# 2                     [40, 50]  /delivery_provider_seamless_20180129.png
# 3                          NaN                                       NaN
# 4                          NaN                                       NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# Stattan Island, Harrow are the best Neightbourhoods in eash city, comparing the crime rates and house prices.

# %% [markdown]
# Statton Island

# %%
latitude = 40.67
longitude = -74.16

search_query = 'Coffee Shop'
radius = 500
LIMIT = 500

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d5c3103e97dfb5ebe18faa9'},
#  'response': {'venues': [{'id': '4c4538b2dcd61b8de27c7c56',
#     'name': 'APM Terminals',
#     'location': {'address': '5080 McLester St',
#      'lat': 40.669067255477025,
#      'lng': -74.15998935699463,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.669067255477025,
#        'lng': -74.15998935699463}],
#      'distance': 103,
#      'postalCode': '07201',
#      'cc': 'US',
#      'city': 'Elizabeth',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['5080 McLester St',
#       'Elizabeth, NJ 07201',
#       'United States']},
#     'categories': [{'id': '4e74f6cabd41c4836eac4c31',
#       'name': 'Pier',
#       'pluralName': 'Piers',
#       'shortName': 'Piers',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/ferry_pier_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566322947',
#     'hasPerk': False},
#    {'id': '4dc3f10745dd264552495537',
#     'name': 'Sealand Chassie Shop',
#     'location': {'address': 'Tripoli St',
#      'lat': 40.668375,
#      'lng': -74.157018,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.668375,
#        'lng': -74.157018}],
#      'distance': 310,
#      'postalCode': '07201',
#      'cc': 'US',
#      'city': 'Elizabeth',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['Tripoli St',
#       'Elizabeth, NJ 07201',
#       'United States']},
#     'categories': [],
#     'referralId': 'v-1566322947',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                          id                  name  \
# 0  4c4538b2dcd61b8de27c7c56         APM Terminals
# 1  4dc3f10745dd264552495537  Sealand Chassie Shop
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4e74f6cabd41c4836eac4c31', 'name': 'P...  v-1566322947    False
# 1                                                 []  v-1566322947    False
#
#    location.address  location.lat  location.lng  \
# 0  5080 McLester St     40.669067    -74.159989
# 1        Tripoli St     40.668375    -74.157018
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 40.66906725547702...                103
# 1  [{'label': 'display', 'lat': 40.668375, 'lng':...                310
#
#   location.postalCode location.cc location.city location.state  \
# 0               07201          US     Elizabeth             NJ
# 1               07201          US     Elizabeth             NJ
#
#   location.country                          location.formattedAddress
# 0    United States  [5080 McLester St, Elizabeth, NJ 07201, United...
# 1    United States   [Tripoli St, Elizabeth, NJ 07201, United States]

# %%
dataframe.shape
# Out:
# (2, 16)

# %% [markdown]
# Coffee shops around Queens, NYC

# %%
latitude = 40.73
longitude = -73.79

search_query = 'Coffee Shop'
radius = 500
LIMIT = 500

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d5c3103018cbb002c8e05e4'},
#  'response': {'venues': [{'id': '59149aae9ad60e49d2fa5e12',
#     'name': 'Poke Coffee',
#     'location': {'address': '17637 Union Tpke',
#      'lat': 40.725797291317086,
#      'lng': -73.79216130810809,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.725797291317086,
#        'lng': -73.79216130810809}],
#      'distance': 502,
#      'postalCode': '11366',
#      'cc': 'US',
#      'city': 'Fresh Meadows',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['17637 Union Tpke',
#       'Fresh Meadows, NY 11366',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '420214323'},
#     'referralId': 'v-1566322947',
#     'hasPerk': False},
#    {'id': '4dc95456fa76d5aaf7a81c07',
#     'name': 'The Patty Shop',
#     'location': {'address': '164-05 89th Ave',
#      'crossStreet': '164',
#      'lat': 40.73001835162937,
#      'lng': -73.79393530106707,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.73001835162937,
#        'lng': -73.79393530106707}],
#      'distance': 331,
#      'postalCode': '11432',
#      'cc': 'US',
#      'city': 'Jamaica',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['164-05 89th Ave (164)',
#       'Jamaica, NY 11432',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d144941735',
#       'name': 'Caribbean Restaurant',
#       'pluralName': 'Caribbean Restaurants',
#       'shortName': 'Caribbean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/caribbean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566322947',
#     'hasPerk': False},
#    {'id': '4c2255d17e85c9288ddcbb21',
#     'name': 'DeLuxe Barbershop',
#     'location': {'address': '80-28 Surrey Pl.',
#      'lat': 40.72623405442939,
#      'lng': -73.78920161459813,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.72623405442939,
#        'lng': -73.78920161459813}],
#      'distance': 424,
#      'postalCode': '11366',
#      'cc': 'US',
#      'city': 'Fresh Meadows',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['80-28 Surrey Pl.',
#       'Fresh Meadows, NY 11366',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110951735',
#       'name': 'Salon / Barbershop',
#       'pluralName': 'Salons / Barbershops',
#       'shortName': 'Salon / Barbershop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566322947',
#     'hasPerk': False},
#    {'id': '50772eb7e4b0e1c6e14ceb97',
#     'name': 'Two Bites Bake Shop',
#     'location': {'address': '181-24 Union Tpke',
#      'lat': 40.72731536914724,
#      'lng': -73.78651064598367,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.72731536914724,
#        'lng': -73.78651064598367}],
#      'distance': 419,
#      'postalCode': '11366',
#      'cc': 'US',
#      'city': 'Fresh Meadows',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['181-24 Union Tpke',
#       'Fresh Meadows, NY 11366',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566322947',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                          id                 name  \
# 0  59149aae9ad60e49d2fa5e12          Poke Coffee
# 1  4dc95456fa76d5aaf7a81c07       The Patty Shop
# 2  4c2255d17e85c9288ddcbb21    DeLuxe Barbershop
# 3  50772eb7e4b0e1c6e14ceb97  Two Bites Bake Shop
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1566322947    False
# 1  [{'id': '4bf58dd8d48988d144941735', 'name': 'C...  v-1566322947    False
# 2  [{'id': '4bf58dd8d48988d110951735', 'name': 'S...  v-1566322947    False
# 3  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...  v-1566322947    False
#
#     location.address  location.lat  location.lng  \
# 0   17637 Union Tpke     40.725797    -73.792161
# 1    164-05 89th Ave     40.730018    -73.793935
# 2   80-28 Surrey Pl.     40.726234    -73.789202
# 3  181-24 Union Tpke     40.727315    -73.786511
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 40.72579729131708...                502
# 1  [{'label': 'display', 'lat': 40.73001835162937...                331
# 2  [{'label': 'display', 'lat': 40.72623405442939...                424
# 3  [{'label': 'display', 'lat': 40.72731536914724...                419
#
#   location.postalCode location.cc  location.city location.state  \
# 0               11366          US  Fresh Meadows             NY
# 1               11432          US        Jamaica             NY
# 2               11366          US  Fresh Meadows             NY
# 3               11366          US  Fresh Meadows             NY
#
#   location.country                          location.formattedAddress  \
# 0    United States  [17637 Union Tpke, Fresh Meadows, NY 11366, Un...
# 1    United States  [164-05 89th Ave (164), Jamaica, NY 11432, Uni...
# 2    United States  [80-28 Surrey Pl., Fresh Meadows, NY 11366, Un...
# 3    United States  [181-24 Union Tpke, Fresh Meadows, NY 11366, U...
#
#   venuePage.id location.crossStreet
# 0    420214323                  NaN
# 1          NaN                  164
# 2          NaN                  NaN
# 3          NaN                  NaN

# %%
dataframe.shape
# Out:
# (4, 18)

# %% [markdown]
# Harrow- Finding the coffee shops around Harrow, UK

# %%
latitude = 51.58
longitude = --0.35

search_query = 'Coffee Shop'
radius = 500
LIMIT = 500

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d5c3104ad1789002c77d98e'},
#  'response': {'venues': []}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# Coffeee shops around Bexley

# %%
latitude = 51.45
longitude = -0.12

search_query = 'Coffee Shop'
radius = 500
LIMIT = 500

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d5c31046e4650002cf1f0ed'},
#  'response': {'venues': [{'id': '56af12d1498e88c71a2dc0a9',
#     'name': 'Stir Coffee',
#     'location': {'address': '111 Brixton Hill',
#      'crossStreet': 'Arodene Rd',
#      'lat': 51.454465,
#      'lng': -0.119599,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.454465,
#        'lng': -0.119599}],
#      'distance': 497,
#      'postalCode': 'SW2 1AA',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['111 Brixton Hill (Arodene Rd)',
#       'London',
#       'Greater London',
#       'SW2 1AA',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '357263313'},
#     'referralId': 'v-1566322948',
#     'hasPerk': False},
#    {'id': '4be5872bd4f7c9b6957b2520',
#     'name': 'Barber Shop',
#     'location': {'lat': 51.448942,
#      'lng': -0.123563,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.448942,
#        'lng': -0.123563}],
#      'distance': 273,
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['United Kingdom']},
#     'categories': [],
#     'referralId': 'v-1566322948',
#     'hasPerk': False},
#    {'id': '58b9e526e6160c18fe5bd741',
#     'name': 'The Little Flower Shop',
#     'location': {'address': '30',
#      'crossStreet': 'New Park Road',
#      'lat': 51.448658120386,
#      'lng': -0.12507140636444092,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.448658120386,
#        'lng': -0.12507140636444092}],
#      'distance': 382,
#      'postalCode': 'SW2 4UN',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['30 (New Park Road)',
#       'London',
#       'Greater London',
#       'SW2 4UN',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d11b951735',
#       'name': 'Flower Shop',
#       'pluralName': 'Flower Shops',
#       'shortName': 'Flower Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/flowershop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566322948',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                          id                    name  \
# 0  56af12d1498e88c71a2dc0a9             Stir Coffee
# 1  4be5872bd4f7c9b6957b2520             Barber Shop
# 2  58b9e526e6160c18fe5bd741  The Little Flower Shop
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1566322948    False
# 1                                                 []  v-1566322948    False
# 2  [{'id': '4bf58dd8d48988d11b951735', 'name': 'F...  v-1566322948    False
#
#    location.address location.crossStreet  location.lat  location.lng  \
# 0  111 Brixton Hill           Arodene Rd     51.454465     -0.119599
# 1               NaN                  NaN     51.448942     -0.123563
# 2                30        New Park Road     51.448658     -0.125071
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 51.454465, 'lng':...                497
# 1  [{'label': 'display', 'lat': 51.448942, 'lng':...                273
# 2  [{'label': 'display', 'lat': 51.448658120386, ...                382
#
#   location.postalCode location.cc location.city  location.state  \
# 0             SW2 1AA          GB        London  Greater London
# 1                 NaN          GB           NaN             NaN
# 2             SW2 4UN          GB        London  Greater London
#
#   location.country                          location.formattedAddress  \
# 0   United Kingdom  [111 Brixton Hill (Arodene Rd), London, Greate...
# 1   United Kingdom                                   [United Kingdom]
# 2   United Kingdom  [30 (New Park Road), London, Greater London, S...
#
#   venuePage.id
# 0    357263313
# 1          NaN
# 2          NaN

# %%
dataframe.shape
# Out:
# (3, 18)
